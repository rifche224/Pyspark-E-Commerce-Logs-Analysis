# %%
import os
os.environ["JAVA_HOME"] = "/opt/homebrew/opt/openjdk@11/libexec/openjdk.jdk/Contents/Home"
os.environ["PATH"] = f"{os.environ['JAVA_HOME']}/bin:" + os.environ["PATH"]

# %%
# import necessary libraries
print("JAVA_HOME =", os.environ.get("JAVA_HOME"))
from pyspark.sql import SparkSession, Window
from pyspark.sql.functions import *
# Out:
# JAVA_HOME = /opt/homebrew/opt/openjdk@11/libexec/openjdk.jdk/Contents/Home

# %%
from pyspark.sql.functions import *

spark = (
    SparkSession.builder
    .appName("E-Commerce Logs Analysis")
    .getOrCreate()
)
# Out:
# Error: LinkageError occurred while loading main class org.apache.spark.launcher.Main
# 	java.lang.UnsupportedClassVersionError: org/apache/spark/launcher/Main has been compiled by a more recent version of the Java Runtime (class file version 61.0), this version of the Java Runtime only recognizes class file versions up to 55.0
# /opt/anaconda3/lib/python3.11/site-packages/pyspark/bin/spark-class: line 97: CMD: bad array subscript
# head: illegal line count -- -1
# ---------------------------------------------------------------------------
# PySparkRuntimeError                       Traceback (most recent call last)
# Cell In[25], line 6
#       1 from pyspark.sql.functions import *
#       3 spark = (
#       4     SparkSession.builder
#       5     .appName("E-Commerce Logs Analysis")
# ----> 6     .getOrCreate()
#       7 )
#
# File /opt/anaconda3/lib/python3.11/site-packages/pyspark/sql/session.py:556, in SparkSession.Builder.getOrCreate(self)
#     554     sparkConf.set(key, value)
#     555 # This SparkContext may be an existing one.
# --> 556 sc = SparkContext.getOrCreate(sparkConf)
#     557 # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     558 # by all sessions.
#     559 session = SparkSession(sc, options=self._options)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pyspark/core/context.py:523, in SparkContext.getOrCreate(cls, conf)
#     521 with SparkContext._lock:
#     522     if SparkContext._active_spark_context is None:
# --> 523         SparkContext(conf=conf or SparkConf())
#     524     assert SparkContext._active_spark_context is not None
#     525     return SparkContext._active_spark_context
#
# File /opt/anaconda3/lib/python3.11/site-packages/pyspark/core/context.py:205, in SparkContext.__init__(self, master, appName, sparkHome, pyFiles, environment, batchSize, serializer, conf, gateway, jsc, profiler_cls, udf_profiler_cls, memory_profiler_cls)
#     199 if gateway is not None and gateway.gateway_parameters.auth_token is None:
#     200     raise ValueError(
#     201         "You are trying to pass an insecure Py4j gateway to Spark. This"
#     202         " is not allowed as it is a security risk."
#     203     )
# --> 205 SparkContext._ensure_initialized(self, gateway=gateway, conf=conf)
#     206 try:
#     207     self._do_init(
#     208         master,
#     209         appName,
#    (...)
#     219         memory_profiler_cls,
#     220     )
#
# File /opt/anaconda3/lib/python3.11/site-packages/pyspark/core/context.py:444, in SparkContext._ensure_initialized(cls, instance, gateway, conf)
#     442 with SparkContext._lock:
#     443     if not SparkContext._gateway:
# --> 444         SparkContext._gateway = gateway or launch_gateway(conf)
#     445         SparkContext._jvm = SparkContext._gateway.jvm
#     447     if instance:
#
# File /opt/anaconda3/lib/python3.11/site-packages/pyspark/java_gateway.py:111, in launch_gateway(conf, popen_kwargs)
#     108     time.sleep(0.1)
#     110 if not os.path.isfile(conn_info_file):
# --> 111     raise PySparkRuntimeError(
#     112         errorClass="JAVA_GATEWAY_EXITED",
#     113         messageParameters={},
#     114     )
#     116 with open(conn_info_file, "rb") as info:
#     117     gateway_port = read_int(info)
#
# PySparkRuntimeError: [JAVA_GATEWAY_EXITED] Java gateway process exited before sending its port number.

# %%
visitors_df = spark.read.format("csv").load("data/user_logs.csv", header=True, inferSchema=True)
visitors_df.toPandas().head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 visitors_df = spark.read.format("csv").load("data/user_logs.csv", header=True, inferSchema=True)
#       2 visitors_df.toPandas().head()
#
# NameError: name 'spark' is not defined
